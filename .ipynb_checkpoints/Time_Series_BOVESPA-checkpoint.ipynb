# %% [markdown]
# #Project for time series study using prophet
# ---

# %% [markdown]
# **STEPS:**
#
# ---
#  [x] Data collection through yahoo finance;
#
#  [x] Series Plot;
#
#  [x] Autocorrelation evaluation of the series;
#
#  [x] Evaluation of additive or multiplicative modeling;
#
#  [x] Analyze using a frequency of weeks;
#
#  [x] Analyze using a frequency of months;
#
#  [x] Make the forecast for the first half of 2021;
#
#
#
# ---
#
# **OBJECTIVES:**
#
# ---
#  [x] Collect the data from the exchange;
#
#  [x] Data Analysis;
#
#  [x] Creat a model;
#
#  [x] Learning more about PROPHET;
#
#  [x] Predict the first half of 2021;
#
#  ---
#
# **FUTURE STEPS:**
#
# ---
#  [ ] Studying algorithm tuning methods;
#
#  [ ] Analyze using a frequency of months;
#
#  [ ] Remove the holidays;
#
#  [ ] External regressors;
#
#  [ ] Predict the year of 2021;
#
#  ---

# %% [markdown]
# #### Loading the main libraries and the time series
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install pandas_datareader 
import pandas_datareader.data as web
# !pip install yfinance #--upgrade --no-cache-dir
import yfinance as yf
# Out:
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.6/dist-packages (0.9.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (4.6.2)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (1.1.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (2.23.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23->pandas_datareader) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23->pandas_datareader) (1.19.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->pandas_datareader) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->pandas_datareader) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->pandas_datareader) (2.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_datareader) (1.15.0)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.6/dist-packages (0.1.55)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from yfinance) (4.6.2)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)

# %%
# Instantiating the library to acquire data
yf.pdr_override()

# %%
# Loading the database with BOVESPA values, within a specific range
from datetime import date
ticker='^BVSP'
data_start='2010-01-01'
print('First Day')
print(data_start)
data_end=date.today().strftime('%Y-%m-%d') 
print('Last Day')
print(data_end)
ibov = web.get_data_yahoo(ticker, start=data_start, end=data_end)
# Out:
# First Day
# 2010-01-01
# Last Day
# 2021-01-29
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# #### Time series analysis
# ---

# %%
# Analysing the first 5 lines from the dataset
ibov.head(5)
# Out:
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2010-01-04  68587.0  70081.0  68587.0  70045.0    70045.0  1655400
# 2010-01-05  70046.0  70595.0  69928.0  70240.0    70240.0  1984200
# 2010-01-06  70237.0  70937.0  70016.0  70729.0    70729.0  2243600
# 2010-01-07  70723.0  70723.0  70045.0  70451.0    70451.0  1555000
# 2010-01-08  70455.0  70766.0  70158.0  70263.0    70263.0  1634400

# %%
# Analysing the last 5 lines from the dataset
ibov.tail(10)
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2021-01-13  123996.0  124032.0  121016.0  122040.0   122040.0  10291500
# 2021-01-14  121947.0  123896.0  121947.0  123481.0   123481.0   8974400
# 2021-01-15  123472.0  123472.0  120374.0  120502.0   120502.0   9387600
# 2021-01-19  121250.0  122120.0  119257.0  120673.0   120673.0   7886000
# 2021-01-20  120645.0  121449.0  118740.0  119708.0   119708.0   7947300
# 2021-01-21  119628.0  120243.0  117785.0  118443.0   118443.0   8573900
# 2021-01-22  118318.0  118318.0  116109.0  117172.0   117172.0   9373100
# 2021-01-26  117381.0  119167.0  116109.0  116464.0   116464.0  10681400
# 2021-01-27  116463.0  117840.0  114887.0  115882.0   115882.0  12380400
# 2021-01-28  115882.0  119314.0  115734.0  119314.0   119314.0  12065900

# %%
# Analysing the type of data from the dataset, and looking for null values
ibov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2735 entries, 2010-01-04 to 2021-01-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2735 non-null   float64
#  1   High       2735 non-null   float64
#  2   Low        2735 non-null   float64
#  3   Close      2735 non-null   float64
#  4   Adj Close  2735 non-null   float64
#  5   Volume     2735 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 149.6 KB

# %%
#Ploting the values of Opening and Closing the BOVESPA
ibov[["Close","Open"]].plot(figsize=(22,8),xlabel='Date',ylabel='Points');

# %% [markdown]
# As at first we are interested in doing a simple analysis to predict the opening or closing value of the exchange with the prophet, I will remove the data for High, Low, Adj and Volume.
#
# ---

# %%
ibov_fillter=ibov[["Close","Open"]]

# %%
#Ploting the values of Opening and Closing the BOVESPA, from the filltred dataset
ibov_fillter.plot(figsize=(22,8),xlabel='Date',ylabel='Points');

# %% [markdown]
# #### Evaluating the autocorrelation
# ---

# %%
# Loading the librarie
from pandas.plotting import autocorrelation_plot

#Looking the Closing Data
autocorrelation_plot(ibov_fillter['Close'])

# %%
#Looking the Opening Data
autocorrelation_plot(ibov_fillter['Open'])

# %% [markdown]
# The correletion plots, graphically summarize the strength of a relationship with an observation in a time series with observations at prior time steps.
#
# The horizontal lines in the plot correspond to 95% and 99% confidence bands.
#
# The dashed line is 99% confidence band.
#
# **Important**
#
# As we can see, both datas has a higher correlation. And just for this inicial studie, I will **consider just the Opening Data** .

# %%
#### Autocorrelation with  the StatsModel
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot

# %% [markdown]
# We have two types of plot, that is heavily used to analyse the correlation in time series:
#
# **Autocorrelation (acf)** and **Partial Autocorrelation (pacf)** plots

# %% [markdown]
# **Autocorrelation (acf)**
#
# Statistical correlation summarizes the strength of the relationship between two variables.
#
# We can assume the distribution of each variable fits a Gaussian (bell curve) distribution. If this is the case, we can use the Pearson’s correlation coefficient to summarize the correlation between the variables.
#
# The Pearson’s correlation coefficient is a number between -1 and 1 that describes a negative or positive correlation respectively. A value of zero indicates no correlation.
#
# We can calculate the correlation for time series observations with observations with previous time steps, called lags. Because the correlation of the time series observations is calculated with values of the same series at previous times, this is called a serial correlation, or an autocorrelation.
#
# A plot of the autocorrelation of a time series by lag is called the AutoCorrelation Function, or the acronym ACF. This plot is sometimes called a correlogram or an autocorrelation plot.
#
# *For exemple the positive values of correlation, means that if the points increase it still increasing*.

# %%
# Autocorrelation plot
plot_acf(ibov_fillter['Open'], lags=300)
pyplot.show()

# %%
# Zooming to better analyze the correlation
plot_acf(ibov_fillter['Open'], lags=25)
pyplot.show()

# %% [markdown]
# **Partial Autocorrelation (pacf)**
#
# A partial autocorrelation is a summary of the relationship between an observation in a time series with observations at prior time steps with the relationships of intervening observations removed.
#
# The partial autocorrelation at lag k is the correlation that results after removing the effect of any correlations due to the terms at shorter lags.
#
# The autocorrelation for an observation and an observation at a prior time step is comprised of both the direct correlation and indirect correlations. These indirect correlations are a linear function of the correlation of the observation, with observations at intervening time steps.
#
# It is these indirect correlations that the partial autocorrelation function seeks to remove. Without going into the math, this is the intuition for the partial autocorrelation.

# %%
# Partial Autocorrelation plot
plot_pacf(ibov_fillter['Open'], lags=300)
pyplot.show()

# %%
plot_pacf(ibov_fillter['Open'], lags=25)
pyplot.show()

# %% [markdown]
# More Explanations cen be found into:
#
# https://machinelearningmastery.com/gentle-introduction-autocorrelation-partial-autocorrelation/
#
# https://www.dummies.com/programming/big-data/data-science/autocorrelation-plots-graphical-technique-for-statistical-data/

# %% [markdown]
# ## Making a week avaliation
# ---

# %%
# Making a resample for a week analysis
resample = ibov_fillter.resample('1W')

# %%
type(resample)
# Out:
# pandas.core.resample.DatetimeIndexResampler

# %%
points_mean_week = resample.mean()

# %%
# Evaluating the null values
points_mean_week.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 578 entries, 2010-01-10 to 2021-01-31
# Freq: W-SUN
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   578 non-null    float64
#  1   Open    578 non-null    float64
# dtypes: float64(2)
# memory usage: 13.5 KB

# %%
# Obserrving the last 5 terms of the dataset, weekly resemple.
points_mean_week.tail(5)
# Out:
#                     Close           Open
# Date
# 2021-01-03  119277.333333  118782.000000
# 2021-01-10  120957.400000  119745.200000
# 2021-01-17  122565.600000  123549.000000
# 2021-01-24  118999.000000  119960.250000
# 2021-01-31  117220.000000  116575.333333

# %%
# Plot of the weekly resemple dataset.
points_mean_week.plot(figsize=(10,5), linewidth=3, fontsize=10, title='BOVESPA Points, weekly resample',ylabel='Points')
pyplot.show()

# %% [markdown]
# ## Creating a baseline considering a forecast with a moving average.
#
# ---

# %%
# Defines a n-element window
n=7
window = n
# Obtains the first n values of the series
history_open = [points_mean_week['Open'].values[i] for i in range(window)]
history_open
# Out:
# [70009.6, 70186.8, 68548.8, 65600.5, 66037.6, 64364.8, 66986.33333333333]

# %%
# Obtains all values after the first n values.
# range(Window_size, series_size)
test_open = [points_mean_week['Open'].values[i] for i in range(window, len(points_mean_week['Open'].values))]
# Displaying the first 5 values after the window
test_open[0:5]
# Out:
# [66554.0, 67397.0, 69376.8, 69547.0, 68920.6]

# %%
# Printing the first 10 elements of the series to check the previous codes
points_mean_week['Open'].head(10)
# Out:
# Date
# 2010-01-10    70009.600000
# 2010-01-17    70186.800000
# 2010-01-24    68548.800000
# 2010-01-31    65600.500000
# 2010-02-07    66037.600000
# 2010-02-14    64364.800000
# 2010-02-21    66986.333333
# 2010-02-28    66554.000000
# 2010-03-07    67397.000000
# 2010-03-14    69376.800000
# Freq: W-SUN, Name: Open, dtype: float64

# %% [markdown]
# ---
#
# Forecast with Mobile Windows
#
# ---

# %%
###############################################################################
# Defines a variable called X_open that is the copy of the data series
###############################################################################
X_open = points_mean_week['Open'].values

###############################################################################
# Defines a n-element window
###############################################################################
n=12
window = n
###############################################################################
# Obtains the first n values of the series
###############################################################################
history = [X_open[i] for i in range(window)]

###############################################################################
# Get all values after the first n (window).
###############################################################################
test = [X_open[i] for i in range(window, len(X_open))]

###############################################################################
# Creating a prediction list (precistion_MoveAverageWindows)
###############################################################################
prediction_MAW = []

###############################################################################
# Looping nos dados
###############################################################################
for t in range(len(test)):

  # Defining the length of the series in analysis
  length = len(history)
  
  # Defining the variable predicted_value_mean as the mean of the n current values.
    #range(start, stop, step)                                                        
  predicted_value_mean = np.mean([history[i] for i in range(length - window, length)])        
  
  # Defines the variable real_value with the current value of the test..
  real_value = test[t]                                                              
  
  # Adding the value into the prediction list
  prediction_MAW.append(predicted_value_mean)                                                  
  
  # Update the history list with the next real value..
  history.append(real_value)                                                        
  
  # Print the predicted value and the real value
  print('Valor predito=%f, Valor real=%f' % (predicted_value_mean, real_value))
# Out:
# Valor predito=67794.152778, Valor real=69739.500000
# Valor predito=67771.644444, Valor real=71221.200000
# Valor predito=67857.844444, Valor real=70876.800000
# Valor predito=68051.844444, Valor real=69305.000000
# Valor predito=68360.552778, Valor real=67905.200000
# Valor predito=68516.186111, Valor real=65568.000000
# Valor predito=68616.452778, Valor real=64553.800000
# Valor predito=68413.741667, Valor real=60998.800000
# Valor predito=67950.808333, Valor real=60324.000000
# Valor predito=67361.391667, Valor real=62439.750000
# Valor predito=66783.304167, Valor real=61837.800000
# Valor predito=66140.870833, Valor real=64175.200000
# Valor predito=65745.420833, Valor real=64635.800000
# Valor predito=65320.112500, Valor real=62636.800000
# Valor predito=64604.745833, Valor real=61913.750000
# Valor predito=63857.825000, Valor real=63419.200000
# Valor predito=63367.341667, Valor real=64072.200000
# Valor predito=63047.925000, Valor real=66637.600000
# Valor predito=63137.058333, Valor real=68144.800000
# Valor predito=63436.308333, Valor real=66980.200000
# Valor predito=63934.758333, Valor real=67015.800000
# Valor predito=64492.408333, Valor real=65291.400000
# Valor predito=64730.045833, Valor real=65777.200000
# Valor predito=65058.329167, Valor real=66612.750000
# Valor predito=65261.458333, Valor real=67659.000000
# Valor predito=65513.391667, Valor real=68021.600000
# Valor predito=65962.125000, Valor real=68981.400000
# Valor predito=66551.095833, Valor real=70474.000000
# Valor predito=67138.995833, Valor real=71283.750000
# Valor predito=67739.958333, Valor real=70698.400000
# Valor predito=68078.358333, Valor real=70149.600000
# Valor predito=68245.425000, Valor real=71785.750000
# Valor predito=68645.887500, Valor real=71953.000000
# Valor predito=69057.320833, Valor real=70010.750000
# Valor predito=69450.600000, Valor real=69493.000000
# Valor predito=69760.250000, Valor real=68544.000000
# Valor predito=69921.187500, Valor real=68944.400000
# Valor predito=70028.304167, Valor real=68277.800000
# Valor predito=70049.654167, Valor real=67982.000000
# Valor predito=69966.370833, Valor real=68320.500000
# Valor predito=69786.912500, Valor real=70251.200000
# Valor predito=69700.866667, Valor real=70597.000000
# Valor predito=69692.416667, Valor real=70417.800000
# Valor predito=69714.766667, Valor real=68832.250000
# Valor predito=69468.641667, Valor real=66911.200000
# Valor predito=69048.491667, Valor real=65039.400000
# Valor predito=68634.212500, Valor real=66783.200000
# Valor predito=68408.395833, Valor real=67124.600000
# Valor predito=68290.112500, Valor real=67190.800000
# Valor predito=68143.979167, Valor real=67102.333333
# Valor predito=68046.023611, Valor real=66619.400000
# Valor predito=67932.473611, Valor real=67293.600000
# Valor predito=67846.898611, Valor real=67794.400000
# Valor predito=67642.165278, Valor real=69407.000000
# Valor predito=67542.998611, Valor real=67309.000000
# Valor predito=67283.931944, Valor real=66090.333333
# Valor predito=67055.438889, Valor real=66617.200000
# Valor predito=67030.938889, Valor real=64585.600000
# Valor predito=66993.122222, Valor real=64338.000000
# Valor predito=66789.355556, Valor real=62990.400000
# Valor predito=66444.838889, Valor real=63153.200000
# Valor predito=66108.372222, Valor real=64099.800000
# Valor predito=65858.161111, Valor real=63424.800000
# Valor predito=65591.944444, Valor real=61881.400000
# Valor predito=65140.927778, Valor real=61214.750000
# Valor predito=64592.623611, Valor real=61855.400000
# Valor predito=63963.323611, Valor real=63020.400000
# Valor predito=63605.940278, Valor real=60358.400000
# Valor predito=63128.279167, Valor real=59358.800000
# Valor predito=62523.412500, Valor real=59314.400000
# Valor predito=62084.145833, Valor real=56695.400000
# Valor predito=61447.262500, Valor real=51500.400000
# Valor predito=60489.762500, Valor real=54125.000000
# Valor predito=59737.412500, Valor real=53090.000000
# Valor predito=58819.929167, Valor real=55645.600000
# Valor predito=58171.662500, Valor real=56435.500000
# Valor predito=57717.837500, Valor real=55935.000000
# Valor predito=57277.858333, Valor real=55989.600000
# Valor predito=56789.041667, Valor real=53515.200000
# Valor predito=55996.941667, Valor real=51419.600000
# Valor predito=55252.041667, Valor real=53238.500000
# Valor predito=54742.016667, Valor real=54588.000000
# Valor predito=54348.150000, Valor real=56973.200000
# Valor predito=54371.300000, Valor real=58331.500000
# Valor predito=54940.558333, Valor real=58354.400000
# Valor predito=55293.008333, Valor real=58083.500000
# Valor predito=55709.133333, Valor real=55828.000000
# Valor predito=55724.333333, Valor real=56251.400000
# Valor predito=55708.991667, Valor real=58491.400000
# Valor predito=55922.025000, Valor real=57213.200000
# Valor predito=56023.991667, Valor real=56454.000000
# Valor predito=56268.891667, Valor real=57477.000000
# Valor predito=56773.675000, Valor real=58754.500000
# Valor predito=57233.341667, Valor real=59474.800000
# Valor predito=57640.575000, Valor real=60681.600000
# Valor predito=57949.608333, Valor real=62534.750000
# Valor predito=58299.879167, Valor real=63583.400000
# Valor predito=58735.629167, Valor real=65540.800000
# Valor predito=59357.070833, Valor real=65252.200000
# Valor predito=60142.420833, Valor real=65952.000000
# Valor predito=60950.804167, Valor real=65955.000000
# Valor predito=61572.770833, Valor real=66561.400000
# Valor predito=62351.787500, Valor real=67493.400000
# Valor predito=63271.737500, Valor real=67079.600000
# Valor predito=64071.954167, Valor real=65696.400000
# Valor predito=64650.445833, Valor real=64388.000000
# Valor predito=65059.879167, Valor real=62538.400000
# Valor predito=65214.612500, Valor real=62480.400000
# Valor predito=65210.083333, Valor real=61994.600000
# Valor predito=65077.683333, Valor real=62010.500000
# Valor predito=64783.491667, Valor real=60373.000000
# Valor predito=64376.891667, Valor real=56629.200000
# Valor predito=63599.991667, Valor real=54964.600000
# Valor predito=62684.125000, Valor real=54521.200000
# Valor predito=61680.775000, Valor real=53364.250000
# Valor predito=60503.345833, Valor real=54893.200000
# Valor predito=59487.812500, Valor real=56430.400000
# Valor predito=58715.645833, Valor real=53762.400000
# Valor predito=57830.179167, Valor real=55459.600000
# Valor predito=57240.279167, Valor real=54021.500000
# Valor predito=56535.370833, Valor real=54310.600000
# Valor predito=55895.037500, Valor real=53308.200000
# Valor predito=55169.845833, Valor real=56339.600000
# Valor predito=54833.729167, Valor real=58209.000000
# Valor predito=54965.379167, Valor real=58824.000000
# Valor predito=55286.995833, Valor real=59038.400000
# Valor predito=55663.429167, Valor real=57914.000000
# Valor predito=56042.575000, Valor real=56860.250000
# Valor predito=56206.495833, Valor real=59607.000000
# Valor predito=56471.212500, Valor real=61813.000000
# Valor predito=57142.095833, Valor real=60892.200000
# Valor predito=57594.812500, Valor real=59011.000000
# Valor predito=58010.604167, Valor real=58823.750000
# Valor predito=58386.700000, Valor real=59659.200000
# Valor predito=58915.950000, Valor real=58056.800000
# Valor predito=59059.050000, Valor real=57298.000000
# Valor predito=58983.133333, Valor real=58418.800000
# Valor predito=58949.366667, Valor real=57039.000000
# Valor predito=58782.750000, Valor real=56131.000000
# Valor predito=58634.166667, Valor real=56984.200000
# Valor predito=58644.495833, Valor real=57725.800000
# Valor predito=58487.729167, Valor real=59226.000000
# Valor predito=58272.145833, Valor real=60379.200000
# Valor predito=58229.395833, Valor real=60794.333333
# Valor predito=58378.006944, Valor real=62286.333333
# Valor predito=58666.555556, Valor real=61765.000000
# Valor predito=58842.038889, Valor real=61863.800000
# Valor predito=59159.288889, Valor real=61881.000000
# Valor predito=59541.205556, Valor real=60143.600000
# Valor predito=59684.938889, Valor real=59335.600000
# Valor predito=59876.322222, Valor real=58325.666667
# Valor predito=60059.211111, Valor real=57029.800000
# Valor predito=60063.011111, Valor real=56991.400000
# Valor predito=60001.811111, Valor real=57224.200000
# Valor predito=59834.994444, Valor real=57969.400000
# Valor predito=59634.177778, Valor real=56361.000000
# Valor predito=59264.733333, Valor real=55460.250000
# Valor predito=58695.893056, Valor real=55469.200000
# Valor predito=58171.243056, Valor real=55530.200000
# Valor predito=57643.443056, Valor real=53589.000000
# Valor predito=56952.443056, Valor real=54611.000000
# Valor predito=56491.393056, Valor real=55097.750000
# Valor predito=56138.238889, Valor real=55689.800000
# Valor predito=55918.583333, Valor real=54787.800000
# Valor predito=55731.750000, Valor real=55980.600000
# Valor predito=55647.516667, Valor real=55869.750000
# Valor predito=55534.645833, Valor real=53433.000000
# Valor predito=55156.612500, Valor real=50576.600000
# Valor predito=54674.579167, Valor real=48795.200000
# Valor predito=54119.158333, Valor real=46930.600000
# Valor predito=53407.608333, Valor real=46142.000000
# Valor predito=52625.258333, Valor real=45635.000000
# Valor predito=51962.425000, Valor real=46841.000000
# Valor predito=51314.925000, Valor real=48448.400000
# Valor predito=50760.812500, Valor real=48913.600000
# Valor predito=50196.129167, Valor real=48147.400000
# Valor predito=49642.762500, Valor real=50511.400000
# Valor predito=49186.995833, Valor real=51082.200000
# Valor predito=48788.033333, Valor real=50703.200000
# Valor predito=48560.550000, Valor real=51507.000000
# Valor predito=48638.083333, Valor real=53773.400000
# Valor predito=49052.933333, Valor real=54538.600000
# Valor predito=49686.933333, Valor real=54235.800000
# Valor predito=50361.416667, Valor real=52968.000000
# Valor predito=50972.500000, Valor real=52623.400000
# Valor predito=51454.366667, Valor real=54727.000000
# Valor predito=51977.583333, Valor real=55643.200000
# Valor predito=52538.383333, Valor real=54440.400000
# Valor predito=53062.800000, Valor real=53683.800000
# Valor predito=53327.166667, Valor real=52227.000000
# Valor predito=53422.566667, Valor real=53367.250000
# Valor predito=53644.570833, Valor real=52044.600000
# Valor predito=53689.370833, Valor real=51017.200000
# Valor predito=53459.687500, Valor real=50662.000000
# Valor predito=53136.637500, Valor real=50527.200000
# Valor predito=52827.587500, Valor real=51261.666667
# Valor predito=52685.393056, Valor real=51048.000000
# Valor predito=52554.109722, Valor real=50458.200000
# Valor predito=52198.376389, Valor real=49729.200000
# Valor predito=51705.543056, Valor real=48814.000000
# Valor predito=51236.676389, Valor real=47631.800000
# Valor predito=50732.343056, Valor real=47092.400000
# Valor predito=50304.459722, Valor real=48055.800000
# Valor predito=49861.838889, Valor real=47357.600000
# Valor predito=49471.255556, Valor real=47143.200000
# Valor predito=49148.422222, Valor real=46925.666667
# Valor predito=48837.061111, Valor real=45754.000000
# Valor predito=48439.294444, Valor real=46016.600000
# Valor predito=48002.205556, Valor real=48235.000000
# Valor predito=47767.788889, Valor real=50719.000000
# Valor predito=47789.522222, Valor real=51445.800000
# Valor predito=47932.572222, Valor real=51282.500000
# Valor predito=48138.280556, Valor real=51868.500000
# Valor predito=48491.338889, Valor real=51562.500000
# Valor predito=48863.847222, Valor real=53539.200000
# Valor predito=49320.797222, Valor real=53866.400000
# Valor predito=49863.197222, Valor real=52941.600000
# Valor predito=50346.397222, Valor real=52527.400000
# Valor predito=50813.208333, Valor real=51654.400000
# Valor predito=51304.908333, Valor real=54295.000000
# Valor predito=51994.775000, Valor real=54732.500000
# Valor predito=52536.233333, Valor real=54009.000000
# Valor predito=52810.400000, Valor real=53284.000000
# Valor predito=52963.583333, Valor real=54023.000000
# Valor predito=53191.958333, Valor real=55570.400000
# Valor predito=53500.450000, Valor real=57606.200000
# Valor predito=54004.091667, Valor real=57068.800000
# Valor predito=54298.225000, Valor real=56280.600000
# Valor predito=54499.408333, Valor real=55997.200000
# Valor predito=54754.041667, Valor real=58169.800000
# Valor predito=55224.241667, Valor real=59840.200000
# Valor predito=55906.391667, Valor real=61394.400000
# Valor predito=56498.008333, Valor real=59015.800000
# Valor predito=56854.950000, Valor real=58291.600000
# Valor predito=57211.833333, Valor real=56786.400000
# Valor predito=57503.700000, Valor real=54466.000000
# Valor predito=57540.616667, Valor real=56690.200000
# Valor predito=57633.933333, Valor real=56338.400000
# Valor predito=57528.283333, Valor real=53108.600000
# Valor predito=57198.266667, Valor real=51631.600000
# Valor predito=56810.850000, Valor real=53858.800000
# Valor predito=56632.650000, Valor real=52645.400000
# Valor predito=56172.283333, Valor real=52123.500000
# Valor predito=55529.225000, Valor real=55377.400000
# Valor predito=55027.808333, Valor real=52470.600000
# Valor predito=54482.375000, Valor real=50368.600000
# Valor predito=53822.125000, Valor real=47846.400000
# Valor predito=53077.125000, Valor real=50221.000000
# Valor predito=52723.375000, Valor real=50250.333333
# Valor predito=52186.719444, Valor real=48690.600000
# Valor predito=51549.402778, Valor real=48139.600000
# Valor predito=51135.319444, Valor real=48663.000000
# Valor predito=50887.936111, Valor real=48266.600000
# Valor predito=50421.919444, Valor real=48418.400000
# Valor predito=50069.669444, Valor real=48889.000000
# Valor predito=49800.127778, Valor real=51073.666667
# Valor predito=49441.483333, Valor real=51592.200000
# Valor predito=49368.283333, Valor real=50946.200000
# Valor predito=49416.416667, Valor real=49046.000000
# Valor predito=49516.383333, Valor real=50045.800000
# Valor predito=49501.783333, Valor real=51559.000000
# Valor predito=49610.838889, Valor real=51212.750000
# Valor predito=49821.018056, Valor real=53607.000000
# Valor predito=50276.634722, Valor real=54416.400000
# Valor predito=50756.084722, Valor real=54507.500000
# Valor predito=51276.159722, Valor real=55806.000000
# Valor predito=51891.793056, Valor real=57139.600000
# Valor predito=52579.343056, Valor real=56836.200000
# Valor predito=53059.554167, Valor real=55792.600000
# Valor predito=53409.587500, Valor real=54164.400000
# Valor predito=53677.770833, Valor real=53390.000000
# Valor predito=54039.770833, Valor real=53233.400000
# Valor predito=54305.404167, Valor real=53533.400000
# Valor predito=54469.937500, Valor real=53681.600000
# Valor predito=54675.675000, Valor real=53194.400000
# Valor predito=54641.291667, Valor real=52196.250000
# Valor predito=54456.279167, Valor real=52984.200000
# Valor predito=54329.337500, Valor real=51227.600000
# Valor predito=53947.804167, Valor real=49546.000000
# Valor predito=53315.004167, Valor real=50273.000000
# Valor predito=52768.070833, Valor real=48676.400000
# Valor predito=52175.054167, Valor real=47083.400000
# Valor predito=51584.970833, Valor real=45666.800000
# Valor predito=50941.370833, Valor real=46618.800000
# Valor predito=50390.154167, Valor real=46607.000000
# Valor predito=49812.954167, Valor real=47629.600000
# Valor predito=49308.620833, Valor real=46150.200000
# Valor predito=48721.604167, Valor real=44659.400000
# Valor predito=48093.533333, Valor real=48077.200000
# Valor predito=47684.616667, Valor real=47644.750000
# Valor predito=47386.045833, Valor real=47313.400000
# Valor predito=47199.995833, Valor real=46843.600000
# Valor predito=46914.212500, Valor real=47421.500000
# Valor predito=46809.637500, Valor real=46653.200000
# Valor predito=46773.787500, Valor real=47011.250000
# Valor predito=46885.825000, Valor real=47712.400000
# Valor predito=46976.958333, Valor real=45469.200000
# Valor predito=46882.141667, Valor real=45348.400000
# Valor predito=46692.041667, Valor real=45027.800000
# Valor predito=46598.508333, Valor real=43533.000000
# Valor predito=46504.641667, Valor real=43816.666667
# Valor predito=46149.597222, Valor real=42073.000000
# Valor predito=45685.284722, Valor real=39704.600000
# Valor predito=45051.218056, Valor real=37990.600000
# Valor predito=44313.468056, Valor real=38135.750000
# Valor predito=43539.655556, Valor real=39991.800000
# Valor predito=42984.538889, Valor real=40095.333333
# Valor predito=42408.212500, Valor real=40792.000000
# Valor predito=41831.512500, Valor real=42254.600000
# Valor predito=41563.629167, Valor real=44122.000000
# Valor predito=41461.429167, Valor real=49135.200000
# Valor predito=41803.712500, Valor real=48864.000000
# Valor predito=42247.962500, Valor real=50669.250000
# Valor predito=42819.011111, Valor real=50596.600000
# Valor predito=43529.311111, Valor real=49000.800000
# Valor predito=44303.994444, Valor real=51608.600000
# Valor predito=45438.827778, Valor real=53366.000000
# Valor predito=46708.015278, Valor real=53332.800000
# Valor predito=47819.765278, Valor real=52792.000000
# Valor predito=48877.820833, Valor real=52356.800000
# Valor predito=49841.554167, Valor real=51024.600000
# Valor predito=50572.387500, Valor real=49466.750000
# Valor predito=51017.783333, Valor real=49075.600000
# Valor predito=51012.816667, Valor real=50859.800000
# Valor predito=51179.133333, Valor real=49208.000000
# Valor predito=51057.362500, Valor real=50484.400000
# Valor predito=51048.012500, Valor real=50381.600000
# Valor predito=51163.079167, Valor real=52114.000000
# Valor predito=51205.195833, Valor real=54288.600000
# Valor predito=51282.079167, Valor real=56395.600000
# Valor predito=51537.312500, Valor real=56837.400000
# Valor predito=51874.429167, Valor real=56981.400000
# Valor predito=52259.812500, Valor real=57641.400000
# Valor predito=52811.212500, Valor real=58957.800000
# Valor predito=53602.133333, Valor real=58064.600000
# Valor predito=54351.216667, Valor real=58209.800000
# Valor predito=54963.716667, Valor real=59882.750000
# Valor predito=55853.279167, Valor real=57673.400000
# Valor predito=56452.362500, Valor real=57915.000000
# Valor predito=57080.145833, Valor real=58568.400000
# Valor predito=57618.012500, Valor real=59614.000000
# Valor predito=58061.795833, Valor real=61234.500000
# Valor predito=58465.037500, Valor real=63117.200000
# Valor predito=58988.354167, Valor real=64027.600000
# Valor predito=59575.537500, Valor real=63577.000000
# Valor predito=60070.170833, Valor real=62854.000000
# Valor predito=60394.854167, Valor real=59843.500000
# Valor predito=60543.095833, Valor real=61276.800000
# Valor predito=60798.679167, Valor real=61363.400000
# Valor predito=60922.066667, Valor real=60675.800000
# Valor predito=61172.266667, Valor real=59117.400000
# Valor predito=61272.466667, Valor real=57598.000000
# Valor predito=61191.600000, Valor real=58759.500000
# Valor predito=61120.391667, Valor real=61067.000000
# Valor predito=61106.433333, Valor real=62382.400000
# Valor predito=61045.200000, Valor real=63987.000000
# Valor predito=61041.816667, Valor real=65577.000000
# Valor predito=61208.483333, Valor real=64887.200000
# Valor predito=61377.916667, Valor real=64598.800000
# Valor predito=61774.191667, Valor real=67120.200000
# Valor predito=62261.141667, Valor real=68278.400000
# Valor predito=62837.391667, Valor real=66507.000000
# Valor predito=63323.325000, Valor real=65636.200000
# Valor predito=63866.558333, Valor real=65380.400000
# Valor predito=64515.091667, Valor real=63834.200000
# Valor predito=64937.983333, Valor real=64716.000000
# Valor predito=65242.066667, Valor real=64989.600000
# Valor predito=78930.112500, Valor real=75034.000000
# Valor predito=78134.979167, Valor real=77244.800000
# Valor predito=77438.329167, Valor real=79075.400000
# Valor predito=76936.550000, Valor real=79650.200000
# Valor predito=76590.133333, Valor real=80164.400000
# Valor predito=76175.166667, Valor real=77305.600000
# Valor predito=75806.683333, Valor real=76014.400000
# Valor predito=75743.633333, Valor real=77287.800000
# Valor predito=75810.200000, Valor real=75669.250000
# Valor predito=76089.637500, Valor real=75469.200000
# Valor predito=76476.087500, Valor real=77352.400000
# Valor predito=76998.737500, Valor real=78947.400000
# Valor predito=77434.570833, Valor real=81169.200000
# Valor predito=77945.837500, Valor real=84540.250000
# Valor predito=78553.791667, Valor real=84332.200000
# Valor predito=78991.858333, Valor real=84465.400000
# Valor predito=79393.125000, Valor real=85961.750000
# Valor predito=79876.237500, Valor real=88004.000000
# Valor predito=80767.770833, Valor real=85512.000000
# Valor predito=81559.237500, Valor real=87779.000000
# Valor predito=82433.504167, Valor real=87705.800000
# Valor predito=83436.550000, Valor real=89151.400000
# Valor predito=84576.733333, Valor real=87054.000000
# Valor predito=85385.200000, Valor real=86282.400000
# Valor predito=85996.450000, Valor real=85431.333333
# Valor predito=86351.627778, Valor real=90158.333333
# Valor predito=86819.801389, Valor real=92596.400000
# Valor predito=87508.484722, Valor real=94391.000000
# Valor predito=88335.618056, Valor real=95943.750000
# Valor predito=89167.451389, Valor real=96643.200000
# Valor predito=89887.384722, Valor real=96762.200000
# Valor predito=90824.901389, Valor real=95959.600000
# Valor predito=91506.618056, Valor real=97035.200000
# Valor predito=92284.068056, Valor real=97123.400000
# Valor predito=92948.401389, Valor real=94278.000000
# Valor predito=93550.401389, Valor real=97752.600000
# Valor predito=94506.251389, Valor real=98697.200000
# Valor predito=95611.740278, Valor real=93800.600000
# Valor predito=95915.262500, Valor real=95539.800000
# Valor predito=96160.545833, Valor real=96293.800000
# Valor predito=96319.112500, Valor real=93394.750000
# Valor predito=96106.695833, Valor real=95334.000000
# Valor predito=95997.595833, Valor real=96076.250000
# Valor predito=95940.433333, Valor real=95159.200000
# Valor predito=95873.733333, Valor real=91944.200000
# Valor predito=95449.483333, Valor real=92941.800000
# Valor predito=95101.016667, Valor real=95772.800000
# Valor predito=95225.583333, Valor real=96928.800000
# Valor predito=95156.933333, Valor real=98270.400000
# Valor predito=95121.366667, Valor real=98844.750000
# Valor predito=95541.712500, Valor real=101117.800000
# Valor predito=96006.545833, Valor real=101713.200000
# Valor predito=96458.162500, Valor real=104900.750000
# Valor predito=97416.995833, Valor real=104012.800000
# Valor predito=98140.229167, Valor real=103350.600000
# Valor predito=98746.425000, Valor real=102637.400000
# Valor predito=99369.608333, Valor real=102366.400000
# Valor predito=100238.125000, Valor real=101689.800000
# Valor predito=100967.125000, Valor real=99945.000000
# Valor predito=101314.808333, Valor real=98022.800000
# Valor predito=101405.975000, Valor real=100983.200000
# Valor predito=101632.041667, Valor real=103582.600000
# Valor predito=102026.862500, Valor real=104137.200000
# Valor predito=102278.479167, Valor real=104623.200000
# Valor predito=102520.979167, Valor real=103283.600000
# Valor predito=102386.216667, Valor real=101235.800000
# Valor predito=102154.800000, Valor real=104604.000000
# Valor predito=102259.250000, Valor real=106750.800000
# Valor predito=102602.033333, Valor real=107747.200000
# Valor predito=103050.433333, Valor real=108725.200000
# Valor predito=103636.716667, Valor real=107198.250000
# Valor predito=104241.154167, Valor real=106549.500000
# Valor predito=104951.712500, Valor real=108033.200000
# Valor predito=105539.212500, Valor real=109411.800000
# Valor predito=106024.979167, Valor real=111187.600000
# Valor predito=106612.512500, Valor real=113305.200000
# Valor predito=107336.012500, Valor real=116062.666667
# Valor predito=108400.934722, Valor real=116915.333333
# Valor predito=109707.562500, Valor real=116688.400000
# Valor predito=110714.595833, Valor real=116717.000000
# Valor predito=111545.112500, Valor real=118458.600000
# Valor predito=112437.729167, Valor real=116043.200000
# Valor predito=113047.562500, Valor real=115035.600000
# Valor predito=113700.675000, Valor real=114807.800000
# Valor predito=114388.866667, Valor real=115155.000000
# Valor predito=114982.350000, Valor real=104347.500000
# Valor predito=114560.325000, Valor real=105175.600000
# Valor predito=114059.325000, Valor real=86795.800000
# Valor predito=111850.208333, Valor real=72709.200000
# Valor predito=108237.419444, Valor real=70612.400000
# Valor predito=104378.841667, Valor real=72856.200000
# Valor predito=100726.158333, Valor real=74652.250000
# Valor predito=97220.762500, Valor real=78619.000000
# Valor predito=93900.795833, Valor real=79579.750000
# Valor predito=90862.175000, Valor real=79514.750000
# Valor predito=87902.104167, Valor real=79217.000000
# Valor predito=84936.204167, Valor real=78797.200000
# Valor predito=81906.387500, Valor real=80773.400000
# Valor predito=79941.879167, Valor real=85646.200000
# Valor predito=78314.429167, Valor real=90779.400000
# Valor predito=78646.395833, Valor real=95927.000000
# Valor predito=80581.212500, Valor real=94076.600000
# Valor predito=82536.562500, Valor real=95650.200000
# Valor predito=84436.062500, Valor real=95414.000000
# Valor predito=86166.208333, Valor real=98481.600000
# Valor predito=87821.425000, Valor real=100303.000000
# Valor predito=89548.362500, Valor real=103641.800000
# Valor predito=91558.950000, Valor real=104317.000000
# Valor predito=93650.616667, Valor real=102761.600000
# Valor predito=95647.650000, Valor real=102197.600000
# Valor predito=97433.000000, Valor real=101066.000000
# Valor predito=98717.983333, Valor real=101438.600000
# Valor predito=99606.250000, Valor real=101267.200000
# Valor predito=100051.266667, Valor real=100354.750000
# Valor predito=100574.445833, Valor real=99743.000000
# Valor predito=100915.512500, Valor real=97063.600000
# Valor predito=101052.979167, Valor real=95067.000000
# Valor predito=100768.429167, Valor real=95836.000000
# Valor predito=100396.179167, Valor real=98591.750000
# Valor predito=99975.341667, Valor real=99997.200000
# Valor predito=99615.358333, Valor real=98764.400000
# Valor predito=99282.258333, Valor real=97146.000000
# Valor predito=98861.291667, Valor real=103371.200000
# Valor predito=99053.391667, Valor real=106130.500000
# Valor predito=99444.383333, Valor real=108715.200000
# Valor predito=100065.050000, Valor real=111013.000000
# Valor predito=100953.237500, Valor real=113854.000000
# Valor predito=102129.154167, Valor real=116431.600000
# Valor predito=103743.154167, Valor real=116827.333333
# Valor predito=105556.515278, Valor real=118782.000000
# Valor predito=107468.681944, Valor real=119745.200000
# Valor predito=109231.469444, Valor real=123549.000000
# Valor predito=111194.119444, Valor real=119960.250000
# Valor predito=112960.440278, Valor real=116575.333333

# %%
# Calculating the Root Mean Square error
from sklearn.metrics import mean_squared_error
rmse_MAW = np.sqrt(mean_squared_error(test, prediction_MAW))

# %%
# Print the value of the rmse
print('Root Mean Square: %.3f' % rmse_MAW)
# Out:
# Root Mean Square: 5483.130

# %%
# Calculating the mean of all Open points
points_mean_all=points_mean_week['Open'].mean()
print(points_mean_all)
# Out:
# 68264.75709342567

# %%
# Evaluating the percentual erro between the mean of all and the RMSE
percentual_avaliation_MAW=(rmse_MAW/points_mean_all)*100

# %%
print('Percentage error between the all point mean and the RMSE : %.3f' % percentual_avaliation_MAW)
# Out:
# Percentage error between the all point mean and the RMSE : 8.032

# %% [markdown]
# ---
#
# Plot of the real values and the predicted values by the Moving Average Window method.
#
# ---

# %%
#############################################
# plot the real values and the predicted ones
#############################################
#pyplot.plot(test, label='Real Value') 
#pyplot.legend()
#pyplot.plot(prediction_MAW, color='red', label='Predicted Value')
#pyplot.legend()
#pyplot.xlabel('Data')
#pyplot.show()

# %%
# Creating tha variable with the time used into the MAW analysis
time_analysis=[points_mean_week.index[i] for i in range(length - window+1)]
# Observing the first 5 responses
time_analysis[0:5]
# Out:
# [Timestamp('2010-01-10 00:00:00', freq='W-SUN'),
#  Timestamp('2010-01-17 00:00:00', freq='W-SUN'),
#  Timestamp('2010-01-24 00:00:00', freq='W-SUN'),
#  Timestamp('2010-01-31 00:00:00', freq='W-SUN'),
#  Timestamp('2010-02-07 00:00:00', freq='W-SUN')]

# %%
# Creating a Data Frame with the real and the prediscted values
d={'TIME':time_analysis, 'MAW': prediction_MAW,'Real':test}
MAW_results=pd.DataFrame(data=d)
# Seting Time as index of the df
MAW_results=MAW_results.set_index('TIME')
# Observing the first 5 lines
MAW_results.head(5)
# Out:
#                      MAW     Real
# TIME
# 2010-01-10  67794.152778  69739.5
# 2010-01-17  67771.644444  71221.2
# 2010-01-24  67857.844444  70876.8
# 2010-01-31  68051.844444  69305.0
# 2010-02-07  68360.552778  67905.2

# %%
############################################################
# Making the Plot to analysis the response of the MAW method
############################################################

MAW_results.plot(figsize=(22,8),xlabel='Date',ylabel='Points');

# %% [markdown]
# ## Creating a new model with PROPHET, to try to get a better result than this one with MAW method.
#
# ---

# %% [markdown]
# Creating Data for making the validation of the model

# %%
# Creating a Split point to separate data for future model validation
# 12=3 months (4 weeks per month)
# Use the last 3 months of the data set to made the validation
split_point = len(points_mean_week['Open']) - 12

# %%
# Dataset for prophet week analysis, with contains the lines until the split_point
dataset_prophet_1week = points_mean_week['Open'][0:split_point]
#len(dataset_prophet_1week)

# %%
# Creating the data for the future validation of the model, it will contains the lest 12 values.
validation_prophet_1week =  points_mean_week['Open'][split_point:]

# %%
# Print the size os the variables
print('Dataset %d, Validation %d' % (len(dataset_prophet_1week), len(validation_prophet_1week)))
# Out:
# Dataset 566, Validation 12

# %% [markdown]
# ---
#
# Now I will evaluate the trend, noise and the seasonality.This evaluation is the decomposition of the time series.
#
# The decomposition is used to understand better the problem during time series analysis and forecasting.
#
# It can be additive or multiplicative, let's use the statsmodels to making this avaliations.
#
# The additive model is Y[t] = T[t] + S[t] + e[t]
#
# The multiplicative model is Y[t] = T[t] * S[t] * e[t]
#
#
# ---

# %%
import pandas.util.testing as tm
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Making the decomposition considering a additive model
result_addtive = seasonal_decompose(points_mean_week['Open'],  model='additive')

# %%
import matplotlib.pyplot as plt
result_addtive.plot()
pyplot.show()

# %%
# Making the decomposition considering a multiplicative model
resultado_mult = seasonal_decompose(points_mean_week['Open'],  model='multiplicative')

# %%
import matplotlib.pyplot as plt
resultado_mult.plot()
pyplot.show()

# %% [markdown]
# ---
#
# Observing the Residual in both models. I can assume that the multiplicative model better describe the time series, because it has the smallest residual error.
#
# ---

# %%
# Making the Augmented Dickey-Fuller test
from statsmodels.tsa.stattools import adfuller
test_estacionariedade = adfuller(points_mean_week['Open'])
#test_estacionariedade

# %%
output = pd.Series(test_estacionariedade[0:4], index = ['Teste', 'p-value','Lags','Number of data used'])
for key, value in test_estacionariedade[4].items():
  output['Valor crítico(%s)' %key] = value

# %%
# Printing the Results
print(output)
# Out:
# Teste                   -0.265180
# p-value                  0.930293
# Lags                    11.000000
# Number of data used    566.000000
# Valor crítico(1%)       -3.441956
# Valor crítico(5%)       -2.866660
# Valor crítico(10%)      -2.569497
# dtype: float64

# %% [markdown]
# **Adfuller test analysis**
#
# ---
# **Null Hypothesis** (H0): If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure.
#
# **Alternate Hypothesis** (H1): The null hypothesis is rejected; it suggests the time series does not have a unit root, meaning it is stationary. It does not have time-dependent structure.
#
# **p-value** > 0.05: **Fail to reject** the **null hypothesis** (H0), the data has a unit root and is non-stationary.
#
# **p-value** <= 0.05: **Reject** the **null hypothesis** (H0), the data does not have a unit root and is stationary.
#
# ---
#
# https://machinelearningmastery.com/time-series-data-stationary-python/

# %% [markdown]
# Analysing the p-value, we can afirme that the time series **fail to reject** the **null hypothesis**, so it is **NON-STATIONARY**. It has a time dependence.

# %%
#!pip install fbprophet

# %% [markdown]
# Start using the **PROPHET**, with the knowledge acquired from the previous analysis.

# %%
# Loading the librarie
from fbprophet import Prophet

# %%
# Creating a dataframe with the time data and the "open" values

dataframe_1week = pd.DataFrame({'ds': dataset_prophet_1week.index, 'y': dataset_prophet_1week.values})
len(dataframe_1week)
# Out:
# 566

# %%
# Observing the result of the dataframe generation
dataframe_1week.tail()
# Out:
#             ds         y
# 561 2020-10-11  95836.00
# 562 2020-10-18  98591.75
# 563 2020-10-25  99997.20
# 564 2020-11-01  98764.40
# 565 2020-11-08  97146.00

# %%
#Creating a multiplicative model
model = Prophet(seasonality_mode='multiplicative')

# %%
# Training the model with the dataframe
model.fit(dataframe_1week)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
validation_prophet_1week.head(N+1)
# Out:
# Date
# 2020-11-15    103371.200000
# 2020-11-22    106130.500000
# 2020-11-29    108715.200000
# 2020-12-06    111013.000000
# 2020-12-13    113854.000000
# 2020-12-20    116431.600000
# 2020-12-27    116827.333333
# 2021-01-03    118782.000000
# 2021-01-10    119745.200000
# 2021-01-17    123549.000000
# 2021-01-24    119960.250000
# 2021-01-31    116575.333333
# Freq: W-SUN, Name: Open, dtype: float64

# %%
# dataset validation
validation_df_1week = pd.DataFrame({'ds': validation_prophet_1week.index, 'y': validation_prophet_1week.values})

# %%
# data estimating
forecast_prediction_1week = model.predict(validation_df_1week)
forecast_prediction_1week[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(N+1)
# Out:
#            ds           yhat     yhat_lower     yhat_upper
# 0  2020-11-15  108047.623313  101037.983336  115212.019715
# 1  2020-11-22  108402.264327  100970.352964  115784.439996
# 2  2020-11-29  108809.196490  101572.726136  116713.627438
# 3  2020-12-06  108946.543960  101871.212696  116701.186102
# 4  2020-12-13  108765.314046  101470.941151  116185.990517
# 5  2020-12-20  108698.897424  101267.835247  115900.379808
# 6  2020-12-27  109319.208327  101986.025675  116974.907746
# 7  2021-01-03  110741.321682  103912.147025  118386.155591
# 8  2021-01-10  112396.429365  105204.345231  119742.930597
# 9  2021-01-17  113465.008440  105972.669874  121030.194163
# 10 2021-01-24  113593.594696  106177.732596  120833.072745
# 11 2021-01-31  113197.397206  105848.830726  120322.432918

# %%
# Creating a dataframe with the results for validation
model_1week_df=pd.DataFrame({'ds': forecast_prediction_1week['ds'],
                             'Real': validation_prophet_1week.values,
                             'Forecast':forecast_prediction_1week['yhat'],
                             'Forecast_up':forecast_prediction_1week['yhat_upper'],
                             'Forecast_down':forecast_prediction_1week['yhat_lower']})
model_1week_df=model_1week_df.set_index('ds');
model_1week_df.head(N+1)
# Out:
#                      Real       Forecast    Forecast_up  Forecast_down
# ds
# 2020-11-15  103371.200000  108047.623313  115212.019715  101037.983336
# 2020-11-22  106130.500000  108402.264327  115784.439996  100970.352964
# 2020-11-29  108715.200000  108809.196490  116713.627438  101572.726136
# 2020-12-06  111013.000000  108946.543960  116701.186102  101871.212696
# 2020-12-13  113854.000000  108765.314046  116185.990517  101470.941151
# 2020-12-20  116431.600000  108698.897424  115900.379808  101267.835247
# 2020-12-27  116827.333333  109319.208327  116974.907746  101986.025675
# 2021-01-03  118782.000000  110741.321682  118386.155591  103912.147025
# 2021-01-10  119745.200000  112396.429365  119742.930597  105204.345231
# 2021-01-17  123549.000000  113465.008440  121030.194163  105972.669874
# 2021-01-24  119960.250000  113593.594696  120833.072745  106177.732596
# 2021-01-31  116575.333333  113197.397206  120322.432918  105848.830726

# %%
# Ploting the validation result
#model_1week_df[['Real','Forecast','Forecast_up','Forecast_down']].plot(figsize=(22,8),xlabel='Date',ylabel='Points');
model_1week_df.plot(figsize=(22,8),xlabel='Date',ylabel='Points');

# %% [markdown]
# ---
#
# **We can se that the model is not making a good fitting with the values, but in the boundary limits contains the most part of the data**
#
# ---

# %%
# Result avaliation
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(model_1week_df['Real'], model_1week_df['Forecast']))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 6094.115

# %% [markdown]
# ## Now, in order to try to upgrade the model, I will make the analysis considering a month frequence.
#
# ---

# %%
# Making a month resample
resample = ibov_fillter.resample('1M')
points_mean_month = resample.mean()

# %%
points_mean_month.head()
# Out:
#                    Close          Open
# Date
# 2010-01-31  68578.157895  68743.578947
# 2010-02-28  65937.555556  65874.500000
# 2010-03-31  69070.391304  68903.913043
# 2010-04-30  69738.050000  69880.550000
# 2010-05-31  62605.285714  62817.761905

# %%
points_mean_month.tail()
# Out:
#                     Close           Open
# Date
# 2020-09-30   98576.142857   98804.857143
# 2020-10-31   97942.000000   97973.047619
# 2020-11-30  105215.842105  104428.210526
# 2020-12-31  115647.000000  115136.150000
# 2021-01-31  120310.058824  120355.176471

# %%
points_mean_month.plot(figsize=(10,5), linewidth=3, fontsize=10, title='BOVESPA Points, month resample',ylabel='Points');
points_mean_week.plot(figsize=(10,5), linewidth=3, fontsize=10, title='BOVESPA Points, weekly resample',ylabel='Points')
pyplot.show()

# %% [markdown]
# ---
#
# We can observe that when we make a monthly resample, we observe that the **oscillation reduced**.
#
# ---

# %%
# Making a new split point, because the frequency of point was, changed.
# In order to making a future prediction for 3 months, N=3.
n_month=3
split_point = len( points_mean_month['Open']) - n_month

# %%
# Creating the dataset for the monthly analysis
dataset_1month = points_mean_month['Open'][0:split_point]

# %%
# Creating the validation dataset for the monthly analysis
validation_1month =  points_mean_month['Open'][split_point:]

# %%
# imprime o tamanho dos conjuntos
print('Dataset %d, Validation %d' % (len(dataset_1month), len(validation_1month)))
# Out:
# Dataset 130, Validation 3

# %%
result_multi = seasonal_decompose(points_mean_month,  model='multiplicative')
result_multi.plot()
pyplot.show()

# %%
result_add = seasonal_decompose(points_mean_month,  model='additive')
result_add.plot()
pyplot.show()

# %% [markdown]
# ---
#  Both models present the **same residual**, sow I will start with the multiplicative because, I use this model into the last analysis.
#
#  ---

# %%
dataframe_1month = pd.DataFrame({'ds':dataset_1month.index, 'y': dataset_1month.values})

# %%
#Creating a multiplciative model
model_month = Prophet(seasonality_mode='multiplicative')

# %%
#training the model
model_month.fit(dataframe_1month)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Gerando dados futuros
# periods=12 periodos para frente
# Freq= Week, Year, Month
future_1month = model_month.make_future_dataframe(periods = 8,
                                                  freq='MS')

# %%
future_1month.tail(7)
# Out:
#             ds
# 131 2020-12-01
# 132 2021-01-01
# 133 2021-02-01
# 134 2021-03-01
# 135 2021-04-01
# 136 2021-05-01
# 137 2021-06-01

# %%
# Forecast future values
forecast_1month = model_month.predict(future_1month)

# %%
# making a interative plot with the values and the forecast
from fbprophet.plot import plot_plotly, plot_components_plotly


plot_plotly(model_month, forecast_1month)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c53ee628-4984-4d74-a47b-9e81ba35d296" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
01-31T00:00:00", "2019-02-28T00:00:00", "2019-03-31T00:00:00", "2019-04-30T00:00:00", "2019-05-31T00:00:00", "2019-06-30T00:00:00", "2019-07-31T00:00:00", "2019-08-31T00:00:00", "2019-09-30T00:00:00", "2019-10-31T00:00:00", "2019-11-30T00:00:00", "2019-12-31T00:00:00", "2020-01-31T00:00:00", "2020-02-29T00:00:00", "2020-03-31T00:00:00", "2020-04-30T00:00:00", "2020-05-31T00:00:00", "2020-06-30T00:00:00", "2020-07-31T00:00:00", "2020-08-31T00:00:00", "2020-09-30T00:00:00", "2020-10-31T00:00:00"], "y": [68743.57894736843, 65874.5, 68903.91304347826, 69880.55, 62817.76190476191, 63431.71428571428, 63831.95238095238, 66682.18181818182, 67588.66666666667, 70559.15, 70526.75, 68472.47619047618, 69917.8, 66475.2, 67157.19047619047, 67553.94736842105, 63799.63636363636, 62405.04761904762, 60603.04761904762, 53942.17391304348, 55597.76190476191, 54368.55, 57164.65, 57415.42857142857, 60580.65, 65292.5, 66671.63636363637, 62715.5, 57468.318181818184, 54668.75, 54536.76190476191, 58166.565217391304, 59947.47368421053, 58684.40909090909, 57197.89473684211, 59391.0, 61594.333333333336, 58005.72222222222, 56851.8, 54779.045454545456, 55572.333333333336, 49933.85, 47131.318181818184, 49981.681818181816, 53524.333333333336, 54087.739130434784, 52909.15789473684, 50846.89473684211, 49319.818181818184, 47412.25, 46872.36842105263, 51413.9, 53143.0, 53557.10526315789, 55670.636 ...

# %%
# Result avaliation
from sklearn.metrics import mean_squared_error
from math import sqrt
predicted_model=forecast_1month.yhat[0:split_point]
rmse = sqrt(mean_squared_error(dataframe_1month.y, predicted_model))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 5826.765

# %%
# Creating the dataset for the validation
validation_df_1month = pd.DataFrame({'ds': validation_1month.index, 'y': validation_1month.values})

# %%
# Predicting the values for the validation
forecast_prediction_1month = model_month.predict(validation_df_1month)
forecast_prediction_1month[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(N+1)
# Out:
#           ds           yhat     yhat_lower     yhat_upper
# 0 2020-11-30  111366.326117  104158.164694  118291.825915
# 1 2020-12-31  111236.565736  104322.942076  118347.832693
# 2 2021-01-31  117531.650019  109918.256347  125070.446252

# %%
# Creating a dataframe with the results for validation
model_1month_df=pd.DataFrame({'ds': forecast_prediction_1month['ds'],
                             'Real': validation_1month.values,
                             'Forecast':forecast_prediction_1month['yhat'],
                             'Forecast_up':forecast_prediction_1month['yhat_upper'],
                             'Forecast_down':forecast_prediction_1month['yhat_lower']})
model_1month_df=model_1month_df.set_index('ds');
model_1month_df.head(N+1)
# Out:
#                      Real       Forecast    Forecast_up  Forecast_down
# ds
# 2020-11-30  104428.210526  111366.326117  118291.825915  104158.164694
# 2020-12-31  115136.150000  111236.565736  118347.832693  104322.942076
# 2021-01-31  120355.176471  117531.650019  125070.446252  109918.256347

# %%
# Ploting the validation result
#model_1week_df[['Real','Forecast','Forecast_up','Forecast_down']].plot(figsize=(22,8),xlabel='Date',ylabel='Points');
model_1month_df.plot(figsize=(22,8),xlabel='Date',ylabel='Points');
